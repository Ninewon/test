# %% [markdown]
# <a href="https://colab.research.google.com/github/Ninewon/test/blob/main/%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("★ 구구단을 출력합니다.\n")
for x in range(2, 10):
    print("------- [" + str(x) + "단] -------")
    for y in range(1, 10):
        print(x, "X", y, "=", x*y)
print("---------------------")

# %% [markdown]
# 파이썬 기초 확실히 배우고싶습니다 제가 배운 코딩이라고는 자바지만 자바도 기초가 많이 부실합니다 이번 기회에 파이썬도 확실하게 배우고싶은 마음이 많이 큽니다 부족하지만 잘부탁드립니다.

# %%
j = int(input())
if j >=10000:
  print("구매 가능")

else
 print("구매 불가능")

# %%
grades=[85, 90, 92, 78, 80, 95]
sum=0
